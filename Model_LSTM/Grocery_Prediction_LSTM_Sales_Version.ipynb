# %%
import pandas as pd
import numpy as np
import datetime

from pyspark.sql import  SparkSession
from pyspark import SparkContext
from pyspark.sql.types import *
from pyspark import SQLContext
import matplotlib.pyplot as plt

from pyspark.sql.functions import col, countDistinct
from pyspark.sql.functions import isnan, when, count, col
from pyspark.sql.functions import year, month, dayofmonth

import matplotlib as plot
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# TIME SERIES
from statsmodels.tsa.arima_model import ARIMA
from statsmodels.tsa.statespace.sarimax import SARIMAX
from pandas.plotting import autocorrelation_plot
from statsmodels.tsa.stattools import adfuller, acf, pacf,arma_order_select_ic


# LSTM
import math
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
# Out:
# /usr/local/anaconda/python2/lib/python2.7/site-packages/statsmodels/compat/pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools
# /usr/local/anaconda/python2/lib/python2.7/site-packages/h5py/__init__.py:34: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
sc = SparkContext()
sqlContext = SQLContext(sc)

# %% [markdown]
# # Transaction & Store Data

# %%
transaction_data = sqlContext.read.csv("/gl-capstone-data/Team6-C-Sep/Data/transactions_store44.csv",header = True,inferSchema = True)

# %%
stores_data=sqlContext.read.csv("/gl-capstone-data/Team6-C-Sep/Data/stores.csv",header = True,inferSchema = True)

# %%
sales_df =pd.merge(transaction_data.toPandas(),stores_data.toPandas(),how='left')
sales_df.describe()
# Out:
#        store_nbr  transactions  cluster
# count     1089.0   1089.000000   1089.0
# mean        44.0   4325.125803      5.0
# std          0.0    749.300106      0.0
# min         44.0   2333.000000      5.0
# 25%         44.0   3797.000000      5.0
# 50%         44.0   4133.000000      5.0
# 75%         44.0   4787.000000      5.0
# max         44.0   8359.000000      5.0

# %%
sales_df.head()
# Out:
#         date  store_nbr  transactions   city      state type  cluster
# 0 2013-01-02         44          4821  Quito  Pichincha    A        5
# 1 2013-01-03         44          3618  Quito  Pichincha    A        5
# 2 2013-01-04         44          4169  Quito  Pichincha    A        5
# 3 2013-01-05         44          4921  Quito  Pichincha    A        5
# 4 2013-01-06         44          4925  Quito  Pichincha    A        5

# %%
sales_df.date.min()
# Out:
# Timestamp('2013-01-02 00:00:00')

# %%
sales_df.date.max()
# Out:
# Timestamp('2015-12-31 00:00:00')

# %% [markdown]
# # Holiday Data

# %%
holiday_data = sqlContext.read.csv("/gl-capstone-data/Team6-C-Sep/Data/holidays_events_2013_2015.csv",header = True,inferSchema = True)
holiday_data_df = holiday_data.toPandas()

# %%
holiday_data_df.head(2)
# Out:
#         date      type    locale locale_name              description  \
# 0 2013-01-01   Holiday  National     Ecuador       Primer dia del ano
# 1 2013-01-05  Work Day  National     Ecuador  Recupero puente Navidad
#
#    transferred
# 0        False
# 1        False

# %%
holiday_data_df['date'] = pd.to_datetime(holiday_data_df['date'], format='%b %d, %Y')
sales_df['date'] = pd.to_datetime(sales_df['date'], format='%b %d, %Y')

# %%
# Isolating events that do not correspond to holidays
events=holiday_data_df.loc[holiday_data_df.type=='Event']
holiday_data_df=holiday_data_df.loc[holiday_data_df.type!='Event']

# %%
# Adjuusting this variable to show all holidays
sales_df['year'],sales_df['week'],sales_df['day']=list(zip(*sales_df.date.apply(lambda x: x.isocalendar())))

# Creating a categorical variable showing weekends
sales_df['dayoff']=[x in [6,7] for x in sales_df.day]

# Adjuusting this variable to show all holidays
for (d,t,l,n) in zip(holiday_data_df.date,holiday_data_df.type,holiday_data_df.locale,holiday_data_df.locale_name):
  if t!='Work Day':
    if l=='National':
      sales_df.loc[sales_df.date==d,'dayoff']=True
    elif l=='Regional':
      sales_df.loc[(sales_df.date==d)&(sales_df.state==n),'dayoff']=True
    else:
      sales_df.loc[(sales_df.date==d)&(sales_df.city==n),'dayoff']=True
  else:
    sales_df.loc[(sales_df.date==d),'dayoff']=False

# %%
sales_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1089 entries, 0 to 1088
# Data columns (total 11 columns):
# date            1089 non-null datetime64[ns]
# store_nbr       1089 non-null int64
# transactions    1089 non-null int64
# city            1089 non-null object
# state           1089 non-null object
# type            1089 non-null object
# cluster         1089 non-null int64
# year            1089 non-null int64
# week            1089 non-null int64
# day             1089 non-null int64
# dayoff          1089 non-null bool
# dtypes: bool(1), datetime64[ns](1), int64(6), object(3)
# memory usage: 94.6+ KB

# %%
holiday_data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 149 entries, 0 to 169
# Data columns (total 6 columns):
# date           149 non-null datetime64[ns]
# type           149 non-null object
# locale         149 non-null object
# locale_name    149 non-null object
# description    149 non-null object
# transferred    149 non-null bool
# dtypes: bool(1), datetime64[ns](1), object(4)
# memory usage: 7.1+ KB

# %%
sales_df.head()
# Out:
#         date  store_nbr  transactions   city      state type  cluster  year  \
# 0 2013-01-02         44          4821  Quito  Pichincha    A        5  2013
# 1 2013-01-03         44          3618  Quito  Pichincha    A        5  2013
# 2 2013-01-04         44          4169  Quito  Pichincha    A        5  2013
# 3 2013-01-05         44          4921  Quito  Pichincha    A        5  2013
# 4 2013-01-06         44          4925  Quito  Pichincha    A        5  2013
#
#    week  day  dayoff
# 0     1    3   False
# 1     1    4   False
# 2     1    5   False
# 3     1    6   False
# 4     1    7    True

# %%
sales_df.count()
# Out:
# date            1089
# store_nbr       1089
# transactions    1089
# city            1089
# state           1089
# type            1089
# cluster         1089
# year            1089
# week            1089
# day             1089
# dayoff          1089
# dtype: int64

# %% [markdown]
# # Oil Data

# %%
sdfOil = sqlContext.read.csv("/gl-capstone-data/Team6-C-Sep/Data/oil.csv",header = True,inferSchema = True)

# %% [markdown]
# # Train Data

# %%
train_data = sqlContext.read.csv("/gl-capstone-data/Team6-C-Sep/Data/train_store44.csv",header = True,inferSchema = True)

# %%
sqlContext.registerDataFrameAsTable(train_data, "traintbl")
train_2015 = sqlContext.sql("select *  from traintbl where date < '2016-01-01 00:00:00'")

# %%
train_2015.head(2)
# Out:
# [Row(id=32292, date=datetime.datetime(2013, 1, 2, 0, 0), store_nbr=44, item_nbr=103520, unit_sales=12.0, onpromotion=None),
#  Row(id=32293, date=datetime.datetime(2013, 1, 2, 0, 0), store_nbr=44, item_nbr=103665, unit_sales=20.0, onpromotion=None)]

# %%
#trainTbl2015 = sqlContext.sql("SELECT date as date,(sum(unit_sales)*count(item_nbr)) as total_sales from traintbl where year(date) <='2015' group by date order by date ")
#trainTbl2015.show()

# %%
# Onpromotion field can't be used as it is strongly associated with Item_nbr
#trainTbl2015 = sqlContext.sql("SELECT date as date,(sum(unit_sales)) as total_sales,onpromotion as onpromotion from traintbl where year(date) <='2015'  group by date,onpromotion order by date ")
#trainTbl2015.show()
#trainTbl2015 = trainTbl2015.fillna({'onpromotion':0})

# %%
trainTbl2015 = sqlContext.sql("SELECT date as date,(sum(unit_sales)) as total_sales from traintbl where year(date) <='2015'  group by date order by date ")
trainTbl2015.show()
# Out:
# +-------------------+------------------+
# |               date|       total_sales|
# +-------------------+------------------+
# |2013-01-02 00:00:00|         30095.181|
# |2013-01-03 00:00:00|20447.056999999997|
# |2013-01-04 00:00:00|22795.799000000003|
# |2013-01-05 00:00:00|31382.508000000005|
# |2013-01-06 00:00:00|         36069.345|
# |2013-01-07 00:00:00|         21025.329|
# |2013-01-08 00:00:00|         33993.257|
# |2013-01-09 00:00:00|         21296.042|
# |2013-01-10 00:00:00|15522.827999999998|
# |2013-01-11 00:00:00|19738.474999999995|
# |2013-01-12 00:00:00|         25418.678|
# |2013-01-13 00:00:00|31129.350000000002|
# |2013-01-14 00:00:00| 17518.41199999999|
# |2013-01-15 00:00:00|15761.720999999996|
# |2013-01-16 00:00:00|21994.872999999996|
# |2013-01-17 00:00:00|14999.144999999997|
# |2013-01-18 00:00:00|         19238.575|
# |2013-01-19 00:00:00|29145.704000000005|
# |2013-01-20 00:00:00|31897.753000000004|
# |2013-01-21 00:00:00|17632.768000000007|
# +-------------------+------------------+
# only showing top 20 rows

# %%
type(trainTbl2015)
# Out:
# pyspark.sql.dataframe.DataFrame

# %%
train_df =pd.merge(trainTbl2015.toPandas(),sales_df,how='left')
train_df.describe()
# Out:
#         total_sales  store_nbr  transactions  cluster         year  \
# count   1089.000000     1089.0   1089.000000   1089.0  1089.000000
# mean   32352.572317       44.0   4325.125803      5.0  2014.004591
# std    13420.765145        0.0    749.300106      0.0     0.817421
# min     9067.748000       44.0   2333.000000      5.0  2013.000000
# 25%    21326.734000       44.0   3797.000000      5.0  2013.000000
# 50%    30586.076000       44.0   4133.000000      5.0  2014.000000
# 75%    39148.231000       44.0   4787.000000      5.0  2015.000000
# max    78070.753000       44.0   8359.000000      5.0  2015.000000
#
#               week          day
# count  1089.000000  1089.000000
# mean     26.620753     4.000000
# std      14.982047     2.003214
# min       1.000000     1.000000
# 25%      14.000000     2.000000
# 50%      27.000000     4.000000
# 75%      40.000000     6.000000
# max      53.000000     7.000000

# %%
train_df.head()
# Out:
#         date  total_sales  store_nbr  transactions   city      state type  \
# 0 2013-01-02    30095.181         44          4821  Quito  Pichincha    A
# 1 2013-01-03    20447.057         44          3618  Quito  Pichincha    A
# 2 2013-01-04    22795.799         44          4169  Quito  Pichincha    A
# 3 2013-01-05    31382.508         44          4921  Quito  Pichincha    A
# 4 2013-01-06    36069.345         44          4925  Quito  Pichincha    A
#
#    cluster  year  week  day  dayoff
# 0        5  2013     1    3   False
# 1        5  2013     1    4   False
# 2        5  2013     1    5   False
# 3        5  2013     1    6   False
# 4        5  2013     1    7    True

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1089 entries, 0 to 1088
# Data columns (total 12 columns):
# date            1089 non-null datetime64[ns]
# total_sales     1089 non-null float64
# store_nbr       1089 non-null int64
# transactions    1089 non-null int64
# city            1089 non-null object
# state           1089 non-null object
# type            1089 non-null object
# cluster         1089 non-null int64
# year            1089 non-null int64
# week            1089 non-null int64
# day             1089 non-null int64
# dayoff          1089 non-null bool
# dtypes: bool(1), datetime64[ns](1), float64(1), int64(6), object(3)
# memory usage: 103.2+ KB

# %%
# Adding feature - Taking 5 lags for prediction LSTM
for obs in range(1,6):
  train_df['T_'+ str(obs)]=train_df.total_sales.shift(obs)

# %%
train_df.head(6)
# Out:
#         date  total_sales  store_nbr  transactions   city      state type  \
# 0 2013-01-02    30095.181         44          4821  Quito  Pichincha    A
# 1 2013-01-03    20447.057         44          3618  Quito  Pichincha    A
# 2 2013-01-04    22795.799         44          4169  Quito  Pichincha    A
# 3 2013-01-05    31382.508         44          4921  Quito  Pichincha    A
# 4 2013-01-06    36069.345         44          4925  Quito  Pichincha    A
# 5 2013-01-07    21025.329         44          3871  Quito  Pichincha    A
#
#    cluster  year  week  day  dayoff        T_1        T_2        T_3  \
# 0        5  2013     1    3   False        NaN        NaN        NaN
# 1        5  2013     1    4   False  30095.181        NaN        NaN
# 2        5  2013     1    5   False  20447.057  30095.181        NaN
# 3        5  2013     1    6   False  22795.799  20447.057  30095.181
# 4        5  2013     1    7    True  31382.508  22795.799  20447.057
# 5        5  2013     2    1   False  36069.345  31382.508  22795.799
#
#          T_4        T_5
# 0        NaN        NaN
# 1        NaN        NaN
# 2        NaN        NaN
# 3        NaN        NaN
# 4  30095.181        NaN
# 5  20447.057  30095.181

# %%
#train_df.onpromotion=train_df.onpromotion.astype('int')
train_df.dayoff=train_df.dayoff.astype('int')
train_df.date = pd.to_datetime(train_df.date)
train_df =train_df.fillna(0)

# %%
train_df.head(10)
# Out:
#         date  total_sales  store_nbr  transactions   city      state type  \
# 0 2013-01-02    30095.181         44          4821  Quito  Pichincha    A
# 1 2013-01-03    20447.057         44          3618  Quito  Pichincha    A
# 2 2013-01-04    22795.799         44          4169  Quito  Pichincha    A
# 3 2013-01-05    31382.508         44          4921  Quito  Pichincha    A
# 4 2013-01-06    36069.345         44          4925  Quito  Pichincha    A
# 5 2013-01-07    21025.329         44          3871  Quito  Pichincha    A
# 6 2013-01-08    33993.257         44          3593  Quito  Pichincha    A
# 7 2013-01-09    21296.042         44          4006  Quito  Pichincha    A
# 8 2013-01-10    15522.828         44          3323  Quito  Pichincha    A
# 9 2013-01-11    19738.475         44          3873  Quito  Pichincha    A
#
#    cluster  year  week  day  dayoff        T_1        T_2        T_3  \
# 0        5  2013     1    3       0      0.000      0.000      0.000
# 1        5  2013     1    4       0  30095.181      0.000      0.000
# 2        5  2013     1    5       0  20447.057  30095.181      0.000
# 3        5  2013     1    6       0  22795.799  20447.057  30095.181
# 4        5  2013     1    7       1  31382.508  22795.799  20447.057
# 5        5  2013     2    1       0  36069.345  31382.508  22795.799
# 6        5  2013     2    2       0  21025.329  36069.345  31382.508
# 7        5  2013     2    3       0  33993.257  21025.329  36069.345
# 8        5  2013     2    4       0  21296.042  33993.257  21025.329
# 9        5  2013     2    5       0  15522.828  21296.042  33993.257
#
#          T_4        T_5
# 0      0.000      0.000
# 1      0.000      0.000
# 2      0.000      0.000
# 3      0.000      0.000
# 4  30095.181      0.000
# 5  20447.057  30095.181
# 6  22795.799  20447.057
# 7  31382.508  22795.799
# 8  36069.345  31382.508
# 9  21025.329  36069.345

# %%
ts=train_df[['date','total_sales']].set_index('date')

# %%
ts=ts.total_sales.astype('float')

# %%
plt.figure(figsize=(8,8))
plt.title('Daily sales in store #44')
plt.xlabel('time')
plt.ylabel('Number of sales')
plt.plot(ts);

# %%
xmask=(train_df.date>=pd.to_datetime("12/01/2015")) & (train_df.date<=pd.to_datetime("12/30/2015"))

# %%
xmas_month=train_df.loc[xmask]

# %%
xmas_month=xmas_month[['date','total_sales']].set_index('date')

# %%
plt.figure(figsize=(8,8))
plt.title('December month Daily sales of 2015 in store #44')
plt.xlabel('time')
plt.ylabel('Number of sales')
plt.plot(xmas_month);
# First week of october has the highest sales in 2015, after 10th sales goes down drastically till 15th

# %%
clean_data=train_df[['day','dayoff','total_sales','T_1','T_2','T_3','T_4','T_5']]

# %%
clean_data.head(6)
# Out:
#    day  dayoff  total_sales        T_1        T_2        T_3        T_4  \
# 0    3       0    30095.181      0.000      0.000      0.000      0.000
# 1    4       0    20447.057  30095.181      0.000      0.000      0.000
# 2    5       0    22795.799  20447.057  30095.181      0.000      0.000
# 3    6       0    31382.508  22795.799  20447.057  30095.181      0.000
# 4    7       1    36069.345  31382.508  22795.799  20447.057  30095.181
# 5    1       0    21025.329  36069.345  31382.508  22795.799  20447.057
#
#          T_5
# 0      0.000
# 1      0.000
# 2      0.000
# 3      0.000
# 4      0.000
# 5  30095.181

# %%
# Predict with validation_split=0.3
X_clean_data=clean_data[['day','dayoff','T_1','T_2','T_3','T_4','T_5']]
Y_clean_data=clean_data['total_sales']

# %%
from sklearn.preprocessing import StandardScaler,MinMaxScaler
scaler=StandardScaler()
X_clean_data_scaled=scaler.fit_transform(X_clean_data)
Y_clean_data_scaled=scaler.fit_transform(Y_clean_data.reshape(len(Y_clean_data),1))
# Out:
# /usr/local/anaconda/python2/lib/python2.7/site-packages/ipykernel_launcher.py:4: FutureWarning: reshape is deprecated and will raise in a subsequent release. Please use .values.reshape(...) instead
#   after removing the cwd from sys.path.

# %%
X_clean_reshaped=X_clean_data_scaled.reshape((X_clean_data_scaled.shape[0],1,X_clean_data_scaled.shape[1]))

# %%
model=Sequential()
model.add(LSTM(5,input_shape=(1,7),kernel_initializer='normal',activation='relu')) # 5 memory cells
model.add(Dense(1,kernel_initializer='normal'))
model.compile(loss='mean_squared_error',optimizer='adam')

# %%
history=model.fit(X_clean_reshaped,Y_clean_data_scaled,validation_split=0.3,
                  epochs=50,batch_size=7,verbose=2) # Every 7 records updates weights in each iteration

#- around 20% - loss: 0.2078 - val_loss: 0.2447  for 50th iteration
# Out:
# Train on 762 samples, validate on 327 samples
# Epoch 1/50
#  - 1s - loss: 0.8996 - val_loss: 1.1231
# Epoch 2/50
#  - 0s - loss: 0.6452 - val_loss: 0.7776
# Epoch 3/50
#  - 0s - loss: 0.3870 - val_loss: 0.4649
# Epoch 4/50
#  - 0s - loss: 0.2995 - val_loss: 0.3552
# Epoch 5/50
#  - 0s - loss: 0.2692 - val_loss: 0.3149
# Epoch 6/50
#  - 0s - loss: 0.2522 - val_loss: 0.2947
# Epoch 7/50
#  - 0s - loss: 0.2441 - val_loss: 0.2847
# Epoch 8/50
#  - 0s - loss: 0.2394 - val_loss: 0.2810
# Epoch 9/50
#  - 0s - loss: 0.2339 - val_loss: 0.2761
# Epoch 10/50
#  - 0s - loss: 0.2305 - val_loss: 0.2752
# Epoch 11/50
#  - 0s - loss: 0.2274 - val_loss: 0.2731
# Epoch 12/50
#  - 0s - loss: 0.2251 - val_loss: 0.2719
# Epoch 13/50
#  - 0s - loss: 0.2229 - val_loss: 0.2682
# Epoch 14/50
#  - 0s - loss: 0.2213 - val_loss: 0.2679
# Epoch 15/50
#  - 0s - loss: 0.2197 - val_loss: 0.2678
# Epoch 16/50
#  - 0s - loss: 0.2187 - val_loss: 0.2672
# Epoch 17/50
#  - 0s - loss: 0.2176 - val_loss: 0.2629
# Epoch 18/50
#  - 0s - loss: 0.2155 - val_loss: 0.2641
# Epoch 19/50
#  - 0s - loss: 0.2144 - val_loss: 0.2621
# Epoch 20/50
#  - 0s - loss: 0.2135 - val_loss: 0.2606
# Epoch 21/50
#  - 0s - loss: 0.2122 - val_loss: 0.2599
# Epoch 22/50
#  - 0s - loss: 0.2112 - val_loss: 0.2581
# Epoch 23/50
#  - 0s - loss: 0.2108 - val_loss: 0.2568
# Epoch 24/50
#  - 0s - loss: 0.2096 - val_loss: 0.2557
# Epoch 25/50
#  - 0s - loss: 0.2091 - val_loss: 0.2546
# Epoch 26/50
#  - 0s - loss: 0.2084 - val_loss: 0.2522
# Epoch 27/50
#  - 0s - loss: 0.2072 - val_loss: 0.2525
# Epoch 28/50
#  - 0s - loss: 0.2062 - val_loss: 0.2516
# Epoch 29/50
#  - 0s - loss: 0.2059 - val_loss: 0.2514
# Epoch 30/50
#  - 0s - loss: 0.2047 - val_loss: 0.2486
# Epoch 31/50
#  - 0s - loss: 0.2038 - val_loss: 0.2476
# Epoch 32/50
#  - 0s - loss: 0.2029 - val_loss: 0.2482
# Epoch 33/50
#  - 0s - loss: 0.2023 - val_loss: 0.2456
# Epoch 34/50
#  - 0s - loss: 0.2022 - val_loss: 0.2439
# Epoch 35/50
#  - 0s - loss: 0.2016 - val_loss: 0.2436
# Epoch 36/50
#  - 0s - loss: 0.2012 - val_loss: 0.2447
# Epoch 37/50
#  - 0s - loss: 0.2010 - val_loss: 0.2413
# Epoch 38/50
#  - 0s - loss: 0.2001 - val_loss: 0.2411
# Epoch 39/50
#  - 0s - loss: 0.2000 - val_loss: 0.2390
# Epoch 40/50
#  - 0s - loss: 0.1994 - val_loss: 0.2382
# Epoch 41/50
#  - 0s - loss: 0.1989 - val_loss: 0.2396
# Epoch 42/50
#  - 0s - loss: 0.1992 - val_loss: 0.2393
# Epoch 43/50
#  - 0s - loss: 0.1982 - val_loss: 0.2365
# Epoch 44/50
#  - 0s - loss: 0.1988 - val_loss: 0.2360
# Epoch 45/50
#  - 0s - loss: 0.1984 - val_loss: 0.2365
# Epoch 46/50
#  - 0s - loss: 0.1975 - val_loss: 0.2352
# Epoch 47/50
#  - 0s - loss: 0.1970 - val_loss: 0.2354
# Epoch 48/50
#  - 0s - loss: 0.1968 - val_loss: 0.2332
# Epoch 49/50
#  - 0s - loss: 0.1970 - val_loss: 0.2352
# Epoch 50/50
#  - 0s - loss: 0.1962 - val_loss: 0.2326

# %%
training_data =train_df[train_df.date < pd.to_datetime("01/01/2014")]
val_mask=(train_df.date >= pd.to_datetime("01/01/2014") ) & (train_df.date < pd.to_datetime("01/01/2015"))
val_data=train_df.loc[val_mask]
test_data=train_df[train_df.date >= pd.to_datetime("01/01/2015")]

# %%
training_data.head(2)
# Out:
#         date  total_sales  store_nbr  transactions   city      state type  \
# 0 2013-01-02    30095.181         44          4821  Quito  Pichincha    A
# 1 2013-01-03    20447.057         44          3618  Quito  Pichincha    A
#
#    cluster  year  week  day  dayoff        T_1  T_2  T_3  T_4  T_5
# 0        5  2013     1    3       0      0.000  0.0  0.0  0.0  0.0
# 1        5  2013     1    4       0  30095.181  0.0  0.0  0.0  0.0

# %%
val_data.head(2)
# Out:
#           date  total_sales  store_nbr  transactions   city      state type  \
# 363 2014-01-02   47024.6300         44          4422  Quito  Pichincha    A
# 364 2014-01-03   42599.8299         44          4167  Quito  Pichincha    A
#
#      cluster  year  week  day  dayoff        T_1        T_2        T_3  \
# 363        5  2014     1    4       0  21858.742  33065.991  25062.428
# 364        5  2014     1    5       0  47024.630  21858.742  33065.991
#
#            T_4        T_5
# 363  25482.503  23745.096
# 364  25062.428  25482.503

# %%
test_data
# Out:
#            date  total_sales  store_nbr  transactions   city      state type  \
# 726  2015-01-02    33283.114         44          4621  Quito  Pichincha    A
# 727  2015-01-03    32598.434         44          4364  Quito  Pichincha    A
# 728  2015-01-04    41727.042         44          5061  Quito  Pichincha    A
# 729  2015-01-05    30253.240         44          4475  Quito  Pichincha    A
# 730  2015-01-06    22941.504         44          3912  Quito  Pichincha    A
# 731  2015-01-07    29337.046         44          4674  Quito  Pichincha    A
# 732  2015-01-08    22956.348         44          4086  Quito  Pichincha    A
# 733  2015-01-09    25093.571         44          4242  Quito  Pichincha    A
# 734  2015-01-10    35426.942         44          5235  Quito  Pichincha    A
# 735  2015-01-11    42871.092         44          5434  Quito  Pichincha    A
# 736  2015-01-12    22810.463         44          3980  Quito  Pichincha    A
# 737  2015-01-13    20298.762         44          3885  Quito  Pichincha    A
# 738  2015-01-14    23638.568         44          4403  Quito  Pichincha    A
# 739  2015-01-15    18840.223         44          3761  Quito  Pichincha    A
# 740  2015-01-16    22759.374         44          3879  Quito  Pichincha    A
# 741  2015-01-17    39148.019         44          5412  Quito  Pichincha    A
# 742  2015-01-18    40449.736         44          5078  Quito  Pichincha    A
# 743  2015-01-19    23644.779         44          3960  Quito  Pichincha    A
# 744  2015-01-20    20288.366         44          3639  Quito  Pichincha    A
# 745  2015-01-21    23173.565         44          4201  Quito  Pichincha    A
# 746  2015-01-22    19664.754         44          3767  Quito  Pichincha    A
# 747  2015-01-23    22837.026         44          4074  Quito  Pichincha    A
# 748  2015-01-24    36935.473         44          5330  Quito  Pichincha    A
# 749  2015-01-25    37607.085         44          5047  Quito  Pichincha    A
# 750  2015-01-26    20581.615         44          3792  Quito  Pichincha    A
# 751  2015-01-27    17723.559         44          3522  Quito  Pichincha    A
# 752  2015-01-28    21931.244         44          4082  Quito  Pichincha    A
# 753  2015-01-29    18275.493         44          3483  Quito  Pichincha    A
# 754  2015-01-30    22037.046         44          4138  Quito  Pichincha    A
# 755  2015-01-31    38255.569         44          5082  Quito  Pichincha    A
# ...         ...          ...        ...           ...    ...        ...  ...
# 1059 2015-12-01    40900.131         44          4326  Quito  Pichincha    A
# 1060 2015-12-02    54551.072         44          4938  Quito  Pichincha    A
# 1061 2015-12-03    33474.826         44          4124  Quito  Pichincha    A
# 1062 2015-12-04    33430.194         44          4234  Quito  Pichincha    A
# 1063 2015-12-05    51688.011         44          4772  Quito  Pichincha    A
# 1064 2015-12-06    69359.288         44          5358  Quito  Pichincha    A
# 1065 2015-12-07    45676.445         44          4618  Quito  Pichincha    A
# 1066 2015-12-08    36447.237         44          4311  Quito  Pichincha    A
# 1067 2015-12-09    49053.009         44          4944  Quito  Pichincha    A
# 1068 2015-12-10    38996.138         44          4584  Quito  Pichincha    A
# 1069 2015-12-11    44265.864         44          5118  Quito  Pichincha    A
# 1070 2015-12-12    63828.272         44          5968  Quito  Pichincha    A
# 1071 2015-12-13    64217.695         44          5672  Quito  Pichincha    A
# 1072 2015-12-14    45300.985         44          4645  Quito  Pichincha    A
# 1073 2015-12-15    41025.348         44          4934  Quito  Pichincha    A
# 1074 2015-12-16    53316.139         44          5492  Quito  Pichincha    A
# 1075 2015-12-17    44663.118         44          5629  Quito  Pichincha    A
# 1076 2015-12-18    50387.702         44          5826  Quito  Pichincha    A
# 1077 2015-12-19    69772.456         44          7085  Quito  Pichincha    A
# 1078 2015-12-20    72234.506         44          6889  Quito  Pichincha    A
# 1079 2015-12-21    62134.692         44          6930  Quito  Pichincha    A
# 1080 2015-12-22    56568.122         44          7502  Quito  Pichincha    A
# 1081 2015-12-23    64755.361         44          8359  Quito  Pichincha    A
# 1082 2015-12-24    43974.551         44          7700  Quito  Pichincha    A
# 1083 2015-12-26    50216.097         44          5549  Quito  Pichincha    A
# 1084 2015-12-27    43531.533         44          4656  Quito  Pichincha    A
# 1085 2015-12-28    36415.460         44          4485  Quito  Pichincha    A
# 1086 2015-12-29    42265.660         44          5143  Quito  Pichincha    A
# 1087 2015-12-30    54848.641         44          5938  Quito  Pichincha    A
# 1088 2015-12-31    40408.634         44          5414  Quito  Pichincha    A
#
#       cluster  year  week  day  dayoff        T_1        T_2        T_3  \
# 726         5  2015     1    5       1  39352.241  44730.547  39928.859
# 727         5  2015     1    6       1  33283.114  39352.241  44730.547
# 728         5  2015     1    7       1  32598.434  33283.114  39352.241
# 729         5  2015     2    1       0  41727.042  32598.434  33283.114
# 730         5  2015     2    2       0  30253.240  41727.042  32598.434
# 731         5  2015     2    3       0  22941.504  30253.240  41727.042
# 732         5  2015     2    4       0  29337.046  22941.504  30253.240
# 733         5  2015     2    5       0  22956.348  29337.046  22941.504
# 734         5  2015     2    6       0  25093.571  22956.348  29337.046
# 735         5  2015     2    7       1  35426.942  25093.571  22956.348
# 736         5  2015     3    1       0  42871.092  35426.942  25093.571
# 737         5  2015     3    2       0  22810.463  42871.092  35426.942
# 738         5  2015     3    3       0  20298.762  22810.463  42871.092
# 739         5  2015     3    4       0  23638.568  20298.762  22810.463
# 740         5  2015     3    5       0  18840.223  23638.568  20298.762
# 741         5  2015     3    6       1  22759.374  18840.223  23638.568
# 742         5  2015     3    7       1  39148.019  22759.374  18840.223
# 743         5  2015     4    1       0  40449.736  39148.019  22759.374
# 744         5  2015     4    2       0  23644.779  40449.736  39148.019
# 745         5  2015     4    3       0  20288.366  23644.779  40449.736
# 746         5  2015     4    4       0  23173.565  20288.366  23644.779
# 747         5  2015     4    5       0  19664.754  23173.565  20288.366
# 748         5  2015     4    6       1  22837.026  19664.754  23173.565
# 749         5  2015     4    7       1  36935.473  22837.026  19664.754
# 750         5  2015     5    1       0  37607.085  36935.473  22837.026
# 751         5  2015     5    2       0  20581.615  37607.085  36935.473
# 752         5  2015     5    3       0  17723.559  20581.615  37607.085
# 753         5  2015     5    4       0  21931.244  17723.559  20581.615
# 754         5  2015     5    5       0  18275.493  21931.244  17723.559
# 755         5  2015     5    6       1  22037.046  18275.493  21931.244
# ...       ...   ...   ...  ...     ...        ...        ...        ...
# 1059        5  2015    49    2       0  39093.603  66294.839  57755.650
# 1060        5  2015    49    3       0  40900.131  39093.603  66294.839
# 1061        5  2015    49    4       0  54551.072  40900.131  39093.603
# 1062        5  2015    49    5       0  33474.826  54551.072  40900.131
# 1063        5  2015    49    6       1  33430.194  33474.826  54551.072
# 1064        5  2015    49    7       1  51688.011  33430.194  33474.826
# 1065        5  2015    50    1       0  69359.288  51688.011  33430.194
# 1066        5  2015    50    2       0  45676.445  69359.288  51688.011
# 1067        5  2015    50    3       0  36447.237  45676.445  69359.288
# 1068        5  2015    50    4       0  49053.009  36447.237  45676.445
# 1069        5  2015    50    5       0  38996.138  49053.009  36447.237
# 1070        5  2015    50    6       1  44265.864  38996.138  49053.009
# 1071        5  2015    50    7       1  63828.272  44265.864  38996.138
# 1072        5  2015    51    1       0  64217.695  63828.272  44265.864
# 1073        5  2015    51    2       0  45300.985  64217.695  63828.272
# 1074        5  2015    51    3       0  41025.348  45300.985  64217.695
# 1075        5  2015    51    4       0  53316.139  41025.348  45300.985
# 1076        5  2015    51    5       0  44663.118  53316.139  41025.348
# 1077        5  2015    51    6       1  50387.702  44663.118  53316.139
# 1078        5  2015    51    7       1  69772.456  50387.702  44663.118
# 1079        5  2015    52    1       1  72234.506  69772.456  50387.702
# 1080        5  2015    52    2       1  62134.692  72234.506  69772.456
# 1081        5  2015    52    3       1  56568.122  62134.692  72234.506
# 1082        5  2015    52    4       1  64755.361  56568.122  62134.692
# 1083        5  2015    52    6       1  43974.551  64755.361  56568.122
# 1084        5  2015    52    7       1  50216.097  43974.551  64755.361
# 1085        5  2015    53    1       0  43531.533  50216.097  43974.551
# 1086        5  2015    53    2       0  36415.460  43531.533  50216.097
# 1087        5  2015    53    3       0  42265.660  36415.460  43531.533
# 1088        5  2015    53    4       1  54848.641  42265.660  36415.460
#
#             T_4        T_5
# 726   42549.199  37877.142
# 727   39928.859  42549.199
# 728   44730.547  39928.859
# 729   39352.241  44730.547
# 730   33283.114  39352.241
# 731   32598.434  33283.114
# 732   41727.042  32598.434
# 733   30253.240  41727.042
# 734   22941.504  30253.240
# 735   29337.046  22941.504
# 736   22956.348  29337.046
# 737   25093.571  22956.348
# 738   35426.942  25093.571
# 739   42871.092  35426.942
# 740   22810.463  42871.092
# 741   20298.762  22810.463
# 742   23638.568  20298.762
# 743   18840.223  23638.568
# 744   22759.374  18840.223
# 745   39148.019  22759.374
# 746   40449.736  39148.019
# 747   23644.779  40449.736
# 748   20288.366  23644.779
# 749   23173.565  20288.366
# 750   19664.754  23173.565
# 751   22837.026  19664.754
# 752   36935.473  22837.026
# 753   37607.085  36935.473
# 754   20581.615  37607.085
# 755   17723.559  20581.615
# ...         ...        ...
# 1059  38206.364  31847.500
# 1060  57755.650  38206.364
# 1061  66294.839  57755.650
# 1062  39093.603  66294.839
# 1063  40900.131  39093.603
# 1064  54551.072  40900.131
# 1065  33474.826  54551.072
# 1066  33430.194  33474.826
# 1067  51688.011  33430.194
# 1068  69359.288  51688.011
# 1069  45676.445  69359.288
# 1070  36447.237  45676.445
# 1071  49053.009  36447.237
# 1072  38996.138  49053.009
# 1073  44265.864  38996.138
# 1074  63828.272  44265.864
# 1075  64217.695  63828.272
# 1076  45300.985  64217.695
# 1077  41025.348  45300.985
# 1078  53316.139  41025.348
# 1079  44663.118  53316.139
# 1080  50387.702  44663.118
# 1081  69772.456  50387.702
# 1082  72234.506  69772.456
# 1083  62134.692  72234.506
# 1084  56568.122  62134.692
# 1085  64755.361  56568.122
# 1086  43974.551  64755.361
# 1087  50216.097  43974.551
# 1088  43531.533  50216.097
#
# [363 rows x 17 columns]

# %%
clean_train=training_data[['day','dayoff','total_sales','T_1','T_2','T_3','T_4','T_5']]
clean_val=val_data[['day','dayoff','total_sales','T_1','T_2','T_3','T_4','T_5']]
clean_test=test_data[['day','dayoff','total_sales','T_1','T_2','T_3','T_4','T_5']]

# %%
clean_train.head(2)
# Out:
#    day  dayoff  total_sales        T_1  T_2  T_3  T_4  T_5
# 0    3       0    30095.181      0.000  0.0  0.0  0.0  0.0
# 1    4       0    20447.057  30095.181  0.0  0.0  0.0  0.0

# %%
clean_val.head(2)
# Out:
#      day  dayoff  total_sales        T_1        T_2        T_3        T_4  \
# 363    4       0   47024.6300  21858.742  33065.991  25062.428  25482.503
# 364    5       0   42599.8299  47024.630  21858.742  33065.991  25062.428
#
#            T_5
# 363  23745.096
# 364  25482.503

# %%
clean_test.head(2)
# Out:
#      day  dayoff  total_sales        T_1        T_2        T_3        T_4  \
# 726    5       1    33283.114  39352.241  44730.547  39928.859  42549.199
# 727    6       1    32598.434  33283.114  39352.241  44730.547  39928.859
#
#            T_5
# 726  37877.142
# 727  42549.199

# %%
X_train,y_train= clean_train.drop(["total_sales"],axis=1),clean_train.total_sales
X_test,y_test= clean_test.drop(["total_sales"],axis=1),clean_test.total_sales
X_val,y_val= clean_val.drop(["total_sales"],axis=1),clean_val.total_sales

# %%
X_train.head(2)
# Out:
#    day  dayoff        T_1  T_2  T_3  T_4  T_5
# 0    3       0      0.000  0.0  0.0  0.0  0.0
# 1    4       0  30095.181  0.0  0.0  0.0  0.0

# %%
# Normalize/Standardize the input and output  data
from sklearn.preprocessing import StandardScaler,MinMaxScaler
scaler=StandardScaler()
X_train_scaled=scaler.fit_transform(X_train)
X_test_scaled=scaler.fit_transform(X_test)
X_val_scaled=scaler.fit_transform(X_val)

y_train_scaled=scaler.fit_transform(y_train.reshape(len(y_train),1))
y_test_scaled=scaler.fit_transform(y_test.reshape(len(y_test),1))
y_val_scaled=scaler.fit_transform(y_val.reshape(len(y_val),1))
# Out:
# /usr/local/anaconda/python2/lib/python2.7/site-packages/ipykernel_launcher.py:8: FutureWarning: reshape is deprecated and will raise in a subsequent release. Please use .values.reshape(...) instead
#
# /usr/local/anaconda/python2/lib/python2.7/site-packages/ipykernel_launcher.py:9: FutureWarning: reshape is deprecated and will raise in a subsequent release. Please use .values.reshape(...) instead
#   if __name__ == '__main__':
# /usr/local/anaconda/python2/lib/python2.7/site-packages/ipykernel_launcher.py:10: FutureWarning: reshape is deprecated and will raise in a subsequent release. Please use .values.reshape(...) instead
#   # Remove the CWD from sys.path while we load stuff.

# %%
X_train_scaled.shape
# Out:
# (363, 7)

# %%
X_train_scaled
# Out:
# array([[-5.00860734e-01, -6.80962317e-01, -3.16675399e+00, ...,
#         -3.07021775e+00, -3.02244724e+00, -2.97669408e+00],
#        [-1.37599103e-03, -6.80962317e-01,  9.98620472e-01, ...,
#         -3.07021775e+00, -3.02244724e+00, -2.97669408e+00],
#        [ 4.98108752e-01, -6.80962317e-01, -3.36744461e-01, ...,
#         -3.07021775e+00, -3.02244724e+00, -2.97669408e+00],
#        ...,
#        [ 1.49707824e+00,  1.46851004e+00,  3.60194966e-01, ...,
#          2.76269525e-02,  2.50379309e-01,  2.04194146e+00],
#        [-1.49983022e+00, -6.80962317e-01,  3.02053774e-01, ...,
#          1.38533907e-01,  3.66490500e-02,  2.55925076e-01],
#        [-1.00034548e+00,  1.46851004e+00,  1.40980046e+00, ...,
#          3.73315337e-01,  1.46168760e-01,  4.48205408e-02]])

# %%
X_test_scaled.shape
# Out:
# (363, 7)

# %%
X_val_scaled.shape
# Out:
# (363, 7)

# %%
# LSTM accepts inputs in 3 Dimension format i.e  Samples, Time steps, feautes
X_t_reshaped=X_train_scaled.reshape((X_train_scaled.shape[0],1,X_train_scaled.shape[1]))
X_val_reshaped=X_val_scaled.reshape((X_val_scaled.shape[0],1,X_val_scaled.shape[1]))

# %%
X_t_reshaped.shape
# Out:
# (363, 1, 7)

# %%
model2=Sequential()
model2.add(LSTM(5,input_shape=(1,7),kernel_initializer='normal',activation='relu'))
model2.add(Dense(1,kernel_initializer='normal'))
model2.compile(loss='mean_squared_error',optimizer='adam') #,metrics=['mse', 'mae', 'mape', 'cosine']

# %%
#validation_split=0.3-

# %%
# Manual validation
history=model2.fit(X_t_reshaped,y_train_scaled,validation_data=(X_val_reshaped,y_val_scaled),
                  epochs=50,batch_size=7,verbose=2)
#  40 % loss
# Out:
# Train on 363 samples, validate on 363 samples
# Epoch 1/50
#  - 1s - loss: 0.9916 - val_loss: 0.9936
# Epoch 2/50
#  - 0s - loss: 0.9633 - val_loss: 0.9730
# Epoch 3/50
#  - 0s - loss: 0.8958 - val_loss: 0.9332
# Epoch 4/50
#  - 0s - loss: 0.7975 - val_loss: 0.8894
# Epoch 5/50
#  - 0s - loss: 0.6900 - val_loss: 0.8360
# Epoch 6/50
#  - 0s - loss: 0.6192 - val_loss: 0.7661
# Epoch 7/50
#  - 0s - loss: 0.5754 - val_loss: 0.6844
# Epoch 8/50
#  - 0s - loss: 0.5338 - val_loss: 0.6169
# Epoch 9/50
#  - 0s - loss: 0.5085 - val_loss: 0.5672
# Epoch 10/50
#  - 0s - loss: 0.4900 - val_loss: 0.5489
# Epoch 11/50
#  - 0s - loss: 0.4789 - val_loss: 0.5098
# Epoch 12/50
#  - 0s - loss: 0.4702 - val_loss: 0.5001
# Epoch 13/50
#  - 0s - loss: 0.4658 - val_loss: 0.4865
# Epoch 14/50
#  - 0s - loss: 0.4606 - val_loss: 0.4801
# Epoch 15/50
#  - 0s - loss: 0.4590 - val_loss: 0.4657
# Epoch 16/50
#  - 0s - loss: 0.4554 - val_loss: 0.4639
# Epoch 17/50
#  - 0s - loss: 0.4539 - val_loss: 0.4718
# Epoch 18/50
#  - 0s - loss: 0.4510 - val_loss: 0.4723
# Epoch 19/50
#  - 0s - loss: 0.4490 - val_loss: 0.4654
# Epoch 20/50
#  - 0s - loss: 0.4467 - val_loss: 0.4663
# Epoch 21/50
#  - 0s - loss: 0.4454 - val_loss: 0.4698
# Epoch 22/50
#  - 0s - loss: 0.4437 - val_loss: 0.4711
# Epoch 23/50
#  - 0s - loss: 0.4418 - val_loss: 0.4713
# Epoch 24/50
#  - 0s - loss: 0.4411 - val_loss: 0.4748
# Epoch 25/50
#  - 0s - loss: 0.4404 - val_loss: 0.4768
# Epoch 26/50
#  - 0s - loss: 0.4391 - val_loss: 0.4731
# Epoch 27/50
#  - 0s - loss: 0.4366 - val_loss: 0.4758
# Epoch 28/50
#  - 0s - loss: 0.4371 - val_loss: 0.4736
# Epoch 29/50
#  - 0s - loss: 0.4341 - val_loss: 0.4799
# Epoch 30/50
#  - 0s - loss: 0.4334 - val_loss: 0.4832
# Epoch 31/50
#  - 0s - loss: 0.4320 - val_loss: 0.4816
# Epoch 32/50
#  - 0s - loss: 0.4306 - val_loss: 0.4829
# Epoch 33/50
#  - 0s - loss: 0.4295 - val_loss: 0.4823
# Epoch 34/50
#  - 0s - loss: 0.4287 - val_loss: 0.4848
# Epoch 35/50
#  - 0s - loss: 0.4279 - val_loss: 0.4866
# Epoch 36/50
#  - 0s - loss: 0.4272 - val_loss: 0.4900
# Epoch 37/50
#  - 0s - loss: 0.4265 - val_loss: 0.4916
# Epoch 38/50
#  - 0s - loss: 0.4243 - val_loss: 0.4936
# Epoch 39/50
#  - 0s - loss: 0.4239 - val_loss: 0.4924
# Epoch 40/50
#  - 0s - loss: 0.4229 - val_loss: 0.4979
# Epoch 41/50
#  - 0s - loss: 0.4215 - val_loss: 0.4955
# Epoch 42/50
#  - 0s - loss: 0.4220 - val_loss: 0.4978
# Epoch 43/50
#  - 0s - loss: 0.4206 - val_loss: 0.4897
# Epoch 44/50
#  - 0s - loss: 0.4196 - val_loss: 0.4961
# Epoch 45/50
#  - 0s - loss: 0.4190 - val_loss: 0.5023
# Epoch 46/50
#  - 0s - loss: 0.4183 - val_loss: 0.5042
# Epoch 47/50
#  - 0s - loss: 0.4186 - val_loss: 0.4988
# Epoch 48/50
#  - 0s - loss: 0.4158 - val_loss: 0.5097
# Epoch 49/50
#  - 0s - loss: 0.4155 - val_loss: 0.5103
# Epoch 50/50
#  - 0s - loss: 0.4151 - val_loss: 0.5049

# %%
plt.plot(history.history['loss'],label='train')
plt.plot(history.history['val_loss'],label='test')
plt.legend()

# %%
X_te_reshaped=X_test_scaled.reshape((X_test_scaled.shape[0],1,X_test_scaled.shape[1]))
res1=model2.predict(X_te_reshaped)
test_data['LS_PRED']=res1
# Out:
# /usr/local/anaconda/python2/lib/python2.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
test_data.head(2)
# Out:
#           date  total_sales  store_nbr  transactions   city      state type  \
# 726 2015-01-02    33283.114         44          4621  Quito  Pichincha    A
# 727 2015-01-03    32598.434         44          4364  Quito  Pichincha    A
#
#      cluster  year  week  day  dayoff        T_1        T_2        T_3  \
# 726        5  2015     1    5       1  39352.241  44730.547  39928.859
# 727        5  2015     1    6       1  33283.114  39352.241  44730.547
#
#            T_4        T_5   LS_PRED
# 726  42549.199  37877.142  0.672095
# 727  39928.859  42549.199  0.743851

# %%
res2=scaler.inverse_transform(res1)

# %%
test_data['LS_PRED_inv']=res2
# Out:
# /usr/local/anaconda/python2/lib/python2.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
test_data.head(2)
# Out:
#           date  total_sales  store_nbr  transactions   city      state type  \
# 726 2015-01-02    33283.114         44          4621  Quito  Pichincha    A
# 727 2015-01-03    32598.434         44          4364  Quito  Pichincha    A
#
#      cluster  year  week  day  dayoff        T_1        T_2        T_3  \
# 726        5  2015     1    5       1  39352.241  44730.547  39928.859
# 727        5  2015     1    6       1  33283.114  39352.241  44730.547
#
#            T_4        T_5   LS_PRED   LS_PRED_inv
# 726  42549.199  37877.142  0.672095  45981.652344
# 727  39928.859  42549.199  0.743851  46955.511719

# %%
plt.plot(test_data['total_sales'],label='Actual')
plt.plot(test_data['LS_PRED_inv'],label='Predicted')
plt.legend()

# %% [markdown]
# # Keras Regression on top of LSTM

# %%
def DL_model2():
    model = Sequential()
    
    model.add(LSTM(5,input_shape=(1,7),kernel_initializer='normal',activation='relu'))
    model.add(Dense(1, kernel_initializer='normal'))
    # Compile model
    model.compile(loss='mean_squared_error', optimizer='adam')
    return model

# %%
from sklearn.model_selection import StratifiedKFold
from keras.wrappers.scikit_learn import KerasRegressor
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
seed=7
np.random.seed(seed)
estimator=KerasRegressor(build_fn=DL_model2,epochs=50,batch_size=5,verbose=0)
kfold=KFold(n_splits=4,random_state=seed)
results=cross_val_score(estimator,X_clean_reshaped,Y_clean_data_scaled,cv=kfold)
print("Baseline : %.2f(%.2f) MSE" %(results.mean(),results.std()))
# Out:
# Baseline : -0.22(0.06) MSE
